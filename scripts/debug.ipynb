# %%
import numpy as np

sdf = np.load("D:/Code/sdf_vis/data/shape_sdf.npy")

print(sdf.shape)  # (1, 64, 64, 64)

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.contourf(sdf, levels=20, cmap='jet')
plt.colorbar()
# equal aspect ratio
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# (32, 32)
